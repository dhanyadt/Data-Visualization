# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanyadt/Data-Visualization/blob/main/Spatialdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install folium

# %%
import folium
from folium import plugins
from IPython.display import HTML, display

# Function to create HTML elements for images
def image_tag(image_url):
    return f'<img src="{image_url}" width="200px">'

# Create a map centered around Bangalore
bangalore_map = folium.Map(location=[12.9716, 77.5946], zoom_start=12)

# Add markers for specific places
places = {
    "Place 1": {"location": [12.9716, 77.5946], "image": "image1.jpg"},
    "Place 2": {"location": [12.9592, 77.6974], "image": "image2.jpg"},
    "Place 3": {"location": [12.9279, 77.6271], "image": "image3.jpg"}
}

for place, info in places.items():
    folium.Marker(location=info['location'], popup=place).add_to(bangalore_map)

    # Add image to marker popup
    iframe = folium.IFrame(html=image_tag(info['image']), width=250, height=250)
    popup = folium.Popup(iframe, max_width=300)
    folium.Marker(location=info['location'], popup=popup).add_to(bangalore_map)

# Display the map
bangalore_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from folium import plugins
from IPython.display import HTML, display

# Function to create HTML elements for images
def image_tag(image_url):
    return f'<img src="{image_url}" width="200px">'

# Create a map centered around Bangalore
bangalore_map = folium.Map(location=[12.9716, 77.5946], zoom_start=10)

# Add markers for specific places
places = {
    "Marathahalli": {"location": [12.9568, 77.7011], "image": "marathahalli_image.jpg"},
    "Whitefield": {"location": [12.9698, 77.7499], "image": "whitefield_image.jpg"},
    "Jakkur": {"location": [13.0785, 77.6068], "image": "jakkur_image.jpg"}
}

for place, info in places.items():
    folium.Marker(location=info['location'], popup=place).add_to(bangalore_map)

    # Add image to marker popup
    iframe = folium.IFrame(html=image_tag(info['image']), width=250, height=250)
    popup = folium.Popup(iframe, max_width=300)
    folium.Marker(location=info['location'], popup=popup).add_to(bangalore_map)

# Display the map
bangalore_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from folium import plugins
from IPython.display import HTML, display

# Function to create HTML elements for images
def image_tag(image_url):
    return f'<img src="{image_url}" width="200px">'

# Create a map centered around Bangalore
bangalore_map = folium.Map(location=[12.9716, 77.5946], zoom_start=10)

# Add markers for specific places
places = {
    "Marathahalli": {"location": [12.9568, 77.7011], "image": "data:image/jpeg;base64,..."},
    "Whitefield": {"location": [12.9698, 77.7499], "image": "data:image/jpeg;base64,..."},
    "Jakkur": {"location": [13.0785, 77.6068], "image": "data:image/jpeg;base64,..."}
}


for place, info in places.items():
    folium.Marker(location=info['location'], popup=place).add_to(bangalore_map)

    # Add image to marker popup
    iframe = folium.IFrame(html=image_tag(info['image']), width=250, height=250)
    popup = folium.Popup(iframe, max_width=300)
    folium.Marker(location=info['location'], popup=popup).add_to(bangalore_map)

# Display the map
bangalore_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from folium import plugins

# Create a map centered around Bangalore
bangalore_map = folium.Map(location=[12.9716, 77.5946], zoom_start=10)

# Add markers for specific places with image URLs and descriptions
places = {
    "Marathahalli": {"location": [12.9568, 77.7011], "image": "data:image/jpeg;base64,...", "description": "MARATHAHALLI : Vibrant commercial and IT area"},
    "Whitefield": {"location": [12.9698, 77.7499], "image": "data:image/jpeg;base64,...", "description": "whitefield: IT hub"},
    "Jakkur": {"location": [13.0785, 77.6068], "image": "data:image/jpeg;base64,...", "description": " JAKKUR : Scenic lake area"}
}

for place, info in places.items():
    # Construct the HTML for the tooltip with image and description
    tooltip_content = f"<img src='{info['image']}' width='200px'><br>{info['description']}"

    # Add the marker with tooltip to the map
    folium.Marker(location=info['location'], tooltip=tooltip_content).add_to(bangalore_map)

# Display the map
bangalore_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
world=gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world.plot()
plt.title('World Countries')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# <ipython-input-22-cc06b82e4cc6>:3: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world=gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
